# %% [markdown]
# # Exercises - Prepare

# %% [markdown]
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.

# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
#nltk.download('all')
from nltk.corpus import stopwords

import pandas as pd
import numpy as np

import acquire

# %%
#nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adamheywood/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# - Lowercase everything

# %%
original = "'title': 'Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia', 'article': '\nBlack excellence in tech: Panelist Spotlight – Wilmarie De La Cruz Mejia\n\nCodeup is hosting a Black Excellence in Tech Panel in honor of Black History Month on February 22, 2023! To further celebrate, we’d like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry!\xa0\xa0\nMeet Wilmarie!\nWilmarie De\xa0La Cruz Mejia is a current Codeup student on the path to becoming a Full-Stack Web Developer at our Dallas, TX campus.\xa0\nWilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with Codeup.\xa0\nWe asked Wilmarie to share more about her experience at Codeup. She shares, “I was able to meet other people who were passionate about coding and be in a positive learning environment.”\nWe hope you can join us on February 22nd to sit in on an insightful conversation with Wilmarie and all of our panelists!\n"

# %%
original = original.lower()
original
# Out:
# "'title': 'black excellence in tech: panelist spotlight – wilmarie de la cruz mejia', 'article': '\nblack excellence in tech: panelist spotlight – wilmarie de la cruz mejia\n\ncodeup is hosting a black excellence in tech panel in honor of black history month on february 22, 2023! to further celebrate, we’d like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry!\xa0\xa0\nmeet wilmarie!\nwilmarie de\xa0la cruz mejia is a current codeup student on the path to becoming a full-stack web developer at our dallas, tx campus.\xa0\nwilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with codeup.\xa0\nwe asked wilmarie to share more about her experience at codeup. she shares, “i was able to meet other people who were passionate about coding and be in a positive learning environment.”\nwe hope you can join us on february 22nd to sit in on an ins
# ...

# %% [markdown]
# - Normalize unicode characters

# %%
original = unicodedata.normalize('NFKD', original).encode('ascii', 'ignore').decode('utf-8')
original
# Out:
# "'title': 'black excellence in tech: panelist spotlight  wilmarie de la cruz mejia', 'article': '\nblack excellence in tech: panelist spotlight  wilmarie de la cruz mejia\n\ncodeup is hosting a black excellence in tech panel in honor of black history month on february 22, 2023! to further celebrate, wed like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry!  \nmeet wilmarie!\nwilmarie de la cruz mejia is a current codeup student on the path to becoming a full-stack web developer at our dallas, tx campus. \nwilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with codeup. \nwe asked wilmarie to share more about her experience at codeup. she shares, i was able to meet other people who were passionate about coding and be in a positive learning environment.\nwe hope you can join us on february 22nd to sit in on an insightful conversation
# ...

# %% [markdown]
# - Replace anything that is not a letter, number, whitespace or a single quote.

# %%
original = re.sub(r'[^a-z0-9\s]', '', original)
original
# Out:
# 'title black excellence in tech panelist spotlight  wilmarie de la cruz mejia article \nblack excellence in tech panelist spotlight  wilmarie de la cruz mejia\n\ncodeup is hosting a black excellence in tech panel in honor of black history month on february 22 2023 to further celebrate wed like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry  \nmeet wilmarie\nwilmarie de la cruz mejia is a current codeup student on the path to becoming a fullstack web developer at our dallas tx campus \nwilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with codeup \nwe asked wilmarie to share more about her experience at codeup she shares i was able to meet other people who were passionate about coding and be in a positive learning environment\nwe hope you can join us on february 22nd to sit in on an insightful conversation with wilmarie and all o
# ...

# %%
original = re.sub(r'[\n]', '', original)
original
# Out:
# 'title black excellence in tech panelist spotlight  wilmarie de la cruz mejia article black excellence in tech panelist spotlight  wilmarie de la cruz mejiacodeup is hosting a black excellence in tech panel in honor of black history month on february 22 2023 to further celebrate wed like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry  meet wilmariewilmarie de la cruz mejia is a current codeup student on the path to becoming a fullstack web developer at our dallas tx campus wilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with codeup we asked wilmarie to share more about her experience at codeup she shares i was able to meet other people who were passionate about coding and be in a positive learning environmentwe hope you can join us on february 22nd to sit in on an insightful conversation with wilmarie and all of our panelists'
# ...

# %%
def basic_clean(string):
    original = string
    original = original.lower()
    original = unicodedata.normalize('NFKD', original).encode('ascii', 'ignore').decode('utf-8')
    original = re.sub(r'[^a-z0-9\s]', '', original)
    original = re.sub(r'[\n]', '', original)
    return original

# %%
string = "'title': 'Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia', 'article': '\nBlack excellence in tech: Panelist Spotlight – Wilmarie De La Cruz Mejia\n\nCodeup is hosting a Black Excellence in Tech Panel in honor of Black History Month on February 22, 2023! To further celebrate, we’d like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry!\xa0\xa0\nMeet Wilmarie!\nWilmarie De\xa0La Cruz Mejia is a current Codeup student on the path to becoming a Full-Stack Web Developer at our Dallas, TX campus.\xa0\nWilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with Codeup.\xa0\nWe asked Wilmarie to share more about her experience at Codeup. She shares, “I was able to meet other people who were passionate about coding and be in a positive learning environment.”\nWe hope you can join us on February 22nd to sit in on an insightful conversation with Wilmarie and all of our panelists!\n'"

# %%
original_test = basic_clean(string)
original_test
# Out:
# 'title black excellence in tech panelist spotlight  wilmarie de la cruz mejia article black excellence in tech panelist spotlight  wilmarie de la cruz mejiacodeup is hosting a black excellence in tech panel in honor of black history month on february 22 2023 to further celebrate wed like to spotlight each of our panelists leading up to the discussion to learn a bit about their respective experiences as black leaders in the tech industry  meet wilmariewilmarie de la cruz mejia is a current codeup student on the path to becoming a fullstack web developer at our dallas tx campus wilmarie is a veteran expanding her knowledge of programming languages and technologies on her journey with codeup we asked wilmarie to share more about her experience at codeup she shares i was able to meet other people who were passionate about coding and be in a positive learning environmentwe hope you can join us on february 22nd to sit in on an insightful conversation with wilmarie and all of our panelists'
# ...

# %% [markdown]
# 2. Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
tokenize = nltk.tokenize.ToktokTokenizer()
tokenize

# %%
original = tokenize.tokenize(original)
original
# Out:
# ['title',
#  'black',
#  'excellence',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmarie',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'article',
#  'black',
#  'excellence',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmarie',
#  'de',
#  'la',
#  'cruz',
#  'mejiacodeup',
#  'is',
#  'hosting',
#  'a',
#  'black',
#  'excellence',
#  'in',
#  'tech',
#  'panel',
#  'in',
#  'honor',
#  'of',
#  'black',
#  'history',
#  'month',
#  'on',
#  'february',
#  '22',
#  '2023',
#  'to',
#  'further',
#  'celebrate',
#  'wed',
#  'like',
#  'to',
#  'spotlight',
#  'each',
#  'of',
#  'our',
#  'panelists',
#  'leading',
#  'up',
#  'to',
#  'the',
#  'discussion',
#  'to',
#  'learn',
#  'a',
#  'bit',
#  'about',
#  'their',
#  'respective',
#  'experiences',
#  'as',
#  'black',
#  'leaders',
#  'in',
#  'the',
#  'tech',
#  'industry',
#  'meet',
#  'wilmariewilmarie',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'is',
#  'a',
#  'current',
#  'codeup',
# ...

# %%
def tokenize(string):
    tokenize = nltk.tokenize.ToktokTokenizer()
    original = tokenize.tokenize(string)
    return original

# %%
tokenize_test = tokenize(original_test)
tokenize_test
# Out:
# ['title',
#  'black',
#  'excellence',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmarie',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'article',
#  'black',
#  'excellence',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmarie',
#  'de',
#  'la',
#  'cruz',
#  'mejiacodeup',
#  'is',
#  'hosting',
#  'a',
#  'black',
#  'excellence',
#  'in',
#  'tech',
#  'panel',
#  'in',
#  'honor',
#  'of',
#  'black',
#  'history',
#  'month',
#  'on',
#  'february',
#  '22',
#  '2023',
#  'to',
#  'further',
#  'celebrate',
#  'wed',
#  'like',
#  'to',
#  'spotlight',
#  'each',
#  'of',
#  'our',
#  'panelists',
#  'leading',
#  'up',
#  'to',
#  'the',
#  'discussion',
#  'to',
#  'learn',
#  'a',
#  'bit',
#  'about',
#  'their',
#  'respective',
#  'experiences',
#  'as',
#  'black',
#  'leaders',
#  'in',
#  'the',
#  'tech',
#  'industry',
#  'meet',
#  'wilmariewilmarie',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'is',
#  'a',
#  'current',
#  'codeup',
# ...

# %% [markdown]
# 3. Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
ps = nltk.porter.PorterStemmer()
ps

# %%
[ps.stem(word) for word in original]
# Out:
# ['titl',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'articl',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejiacodeup',
#  'is',
#  'host',
#  'a',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panel',
#  'in',
#  'honor',
#  'of',
#  'black',
#  'histori',
#  'month',
#  'on',
#  'februari',
#  '22',
#  '2023',
#  'to',
#  'further',
#  'celebr',
#  'wed',
#  'like',
#  'to',
#  'spotlight',
#  'each',
#  'of',
#  'our',
#  'panelist',
#  'lead',
#  'up',
#  'to',
#  'the',
#  'discuss',
#  'to',
#  'learn',
#  'a',
#  'bit',
#  'about',
#  'their',
#  'respect',
#  'experi',
#  'as',
#  'black',
#  'leader',
#  'in',
#  'the',
#  'tech',
#  'industri',
#  'meet',
#  'wilmariewilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'is',
#  'a',
#  'current',
#  'codeup',
#  'student',
#  'on',
#  'the',
#  'path',
# ...

# %%
stems = [ps.stem(word) for word in original]
' '.join(stems)
# Out:
# 'titl black excel in tech panelist spotlight wilmari de la cruz mejia articl black excel in tech panelist spotlight wilmari de la cruz mejiacodeup is host a black excel in tech panel in honor of black histori month on februari 22 2023 to further celebr wed like to spotlight each of our panelist lead up to the discuss to learn a bit about their respect experi as black leader in the tech industri meet wilmariewilmari de la cruz mejia is a current codeup student on the path to becom a fullstack web develop at our dalla tx campu wilmari is a veteran expand her knowledg of program languag and technolog on her journey with codeup we ask wilmari to share more about her experi at codeup she share i wa abl to meet other peopl who were passion about code and be in a posit learn environmentw hope you can join us on februari 22nd to sit in on an insight convers with wilmari and all of our panelist'

# %%
stems
# Out:
# ['titl',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'articl',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejiacodeup',
#  'is',
#  'host',
#  'a',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panel',
#  'in',
#  'honor',
#  'of',
#  'black',
#  'histori',
#  'month',
#  'on',
#  'februari',
#  '22',
#  '2023',
#  'to',
#  'further',
#  'celebr',
#  'wed',
#  'like',
#  'to',
#  'spotlight',
#  'each',
#  'of',
#  'our',
#  'panelist',
#  'lead',
#  'up',
#  'to',
#  'the',
#  'discuss',
#  'to',
#  'learn',
#  'a',
#  'bit',
#  'about',
#  'their',
#  'respect',
#  'experi',
#  'as',
#  'black',
#  'leader',
#  'in',
#  'the',
#  'tech',
#  'industri',
#  'meet',
#  'wilmariewilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'is',
#  'a',
#  'current',
#  'codeup',
#  'student',
#  'on',
#  'the',
#  'path',
# ...

# %%
def stem_func(string2):
    ps = nltk.porter.PorterStemmer()
    stems2 = [ps.stem(word) for word in string2]
    ' '.join(stems2)
    return stems2

# %%
stems_test = stem_func(tokenize_test)
stems_test
# Out:
# ['titl',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'articl',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panelist',
#  'spotlight',
#  'wilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejiacodeup',
#  'is',
#  'host',
#  'a',
#  'black',
#  'excel',
#  'in',
#  'tech',
#  'panel',
#  'in',
#  'honor',
#  'of',
#  'black',
#  'histori',
#  'month',
#  'on',
#  'februari',
#  '22',
#  '2023',
#  'to',
#  'further',
#  'celebr',
#  'wed',
#  'like',
#  'to',
#  'spotlight',
#  'each',
#  'of',
#  'our',
#  'panelist',
#  'lead',
#  'up',
#  'to',
#  'the',
#  'discuss',
#  'to',
#  'learn',
#  'a',
#  'bit',
#  'about',
#  'their',
#  'respect',
#  'experi',
#  'as',
#  'black',
#  'leader',
#  'in',
#  'the',
#  'tech',
#  'industri',
#  'meet',
#  'wilmariewilmari',
#  'de',
#  'la',
#  'cruz',
#  'mejia',
#  'is',
#  'a',
#  'current',
#  'codeup',
#  'student',
#  'on',
#  'the',
#  'path',
# ...

# %% [markdown]
# 4. Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
wnl = nltk.stem.WordNetLemmatizer()
wnl

# %%
lemmas = [wnl.lemmatize(word) for word in original]
' '.join(lemmas)

# %%
lemmas

# %%
def lemmatize(string):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in original]
    ' '.join(lemmas)

# %%
lemmas_test = lemmatize(tokenize_test)
lemmas_test

# %% [markdown]
# 5. Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.

# %% [markdown]
# This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
nltk.download('stopwords')

# %%
original

# %%
stopwords_english = stopwords.words('english')

# %%
stopwords_english.append('o')

# %%
original_with_stopwords_removed = [word for word in original if word not in stopwords_english]
' '.join(original_with_stopwords_removed)

# %%
def remove_stopwords(string, language='english', extra_words=''):
    stop_lang = stopwords.words(language)
    #stop_lang = stop_lang.remove(exclude_words)
    stop_lang = stop_lang.append(extra_words)
    original_with_stopwords_removed = [word for word in string if word not in stop_lang]
    ' '.join(original_with_stopwords_removed)
    return original_with_stopwords_removed

# %%
stopwords_test = remove_stopwords(tokenize_test)
stopwords_test

# %% [markdown]
# 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
topic_list = ['business', 'sports', 'technology', 'entertainment']

# %%
get_news = acquire.get_news_articles(topic_list)

# %%
get_news
# Out:
# [{'category': 'business',
#   'title': 'Sachin Tendulkar and his wife meet Bill Gates; share pics',
#   'content': 'Former cricketer Sachin Tendulkar and his wife Anjali Tendulkar met with Microsoft Co-founder Bill Gates in Mumbai on Tuesday. Sharing pictures of the meeting on social media, Sachin Tendulkar wrote, "We are all students for life. Today was a wonderful learning opportunity to gain perspectives on philanthropy - including children\'s healthcare, which our Foundation works on." '},
#  {'category': 'business',
#   'title': "'Best wishes to my classmate,' writes Gates in book gifted to Mahindra, latter shares pic",
# ...

# %%
news_df = acquire.get_news_articles(topic_list)

# %%
news_df = pd.DataFrame(news_df)

# %%
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                               content
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %% [markdown]
# 7. Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
links_list = ['https://codeup.com/codeup-news/panelist-spotlight-4/',
 'https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-stephanie-jones/',
 'https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-james-cooper/',
 'https://codeup.com/events/black-excellence-in-tech-panelist-spotlight/',
 'https://codeup.com/tips-for-prospective-students/coding-bootcamp-or-self-learning/',
 'https://codeup.com/codeup-news/codeup-best-bootcamps/']

# %%
codeup_df = acquire.get_blog_articles(links_list)

# %%
codeup_df
# Out:
# [{'title': 'Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia',
#   'link': 'https://codeup.com/codeup-news/panelist-spotlight-4/',
#   'date_published': 'Feb 16, 2023',
# ...

# %%
codeup_df = pd.DataFrame(codeup_df)
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                              content
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %% [markdown]
# 8. For each dataframe, produce the following columns:
#
# - title to hold the title
# - original to hold the original article/post content
# - clean to hold the normalized and tokenized original with the stopwords removed.
# - stemmed to hold the stemmed version of the cleaned data.
# - lemmatized to hold the lemmatized version of the cleaned data.

# %%
codeup_df = codeup_df.rename(columns={'content': 'original'})

# %%
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                             original
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %%
def basic_clean(string):
    original = string
    original = original.lower()
    original = unicodedata.normalize('NFKD', original).encode('ascii', 'ignore').decode('utf-8')
    original = re.sub(r'[^a-z0-9\s]', '', original)
    original = re.sub(r'[\n]', '', original)
    return original

# %%
codeup_df['original'].apply(basic_clean)
# Out:
# 0    black excellence in tech panelist spotlight  w...
# 1    black excellence in tech panelist spotlight  s...
# 2    black excellence in tech panelist spotlight  j...
# 3    black excellence in tech panelist spotlight  j...
# 4    if youre interested in embarking on a career i...
# 5    codeup is pleased to announce we have been ran...
# Name: original, dtype: object

# %%
codeup_df['clean'] = codeup_df['original'].apply(basic_clean)
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                             original  \
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %%
def tokenize(string):
    tokenize = nltk.tokenize.ToktokTokenizer()
    original = tokenize.tokenize(string)
    return string

# %%
codeup_df['clean'] = codeup_df['clean'].apply(tokenize)
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                             original  \
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %%
def remove_stopwords(string, extra_words = [], exclude_words = []):
    stop_lang = stopwords.words(language)
    #stop_lang = stop_lang.remove(exclude_words)
    #stop_lang = stop_lang.append(extra_words)
    original_with_stopwords_removed = [word for word in string if word not in stop_lang]
    ' '.join(original_with_stopwords_removed)
    return string

# %%
codeup_df['clean'] = codeup_df['clean'].apply(remove_stopwords)
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                             original  \
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %%
def stem_func(string):
    ps = nltk.porter.PorterStemmer()
    stems = [ps.stem(word) for word in string]
    ' '.join(stems)
    return string

# %%
codeup_df['stemmed'] = codeup_df['clean'].apply(stem_func)
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                             original  \
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %%
def lemmatize(string3):
    wnl = nltk.stem.WordNetLemmatizer()
    lemmas = [wnl.lemmatize(word) for word in string3]
    ' '.join(lemmas)
    return string3

# %%
codeup_df['lemmatized'] = codeup_df['clean'].apply(lemmatize)
codeup_df
# Out:
#                                                title  \
# 0  Black Excellence in Tech: Panelist Spotlight –...
# 1  Black excellence in tech: Panelist Spotlight –...
# 2  Black excellence in tech: Panelist Spotlight –...
# 3  Black excellence in tech: Panelist Spotlight –...
# 4  Coding Bootcamp or Self-Learning? Which is Bes...
# 5  Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                 link date_published  \
# 0  https://codeup.com/codeup-news/panelist-spotli...   Feb 16, 2023
# 1  https://codeup.com/events/black-excellence-in-...   Feb 13, 2023
# 2  https://codeup.com/events/black-excellence-in-...   Feb 10, 2023
# 3  https://codeup.com/events/black-excellence-in-...    Feb 6, 2023
# 4  https://codeup.com/tips-for-prospective-studen...   Jan 20, 2023
# 5  https://codeup.com/codeup-news/codeup-best-boo...   Jan 12, 2023
#
#                                             original  \
# 0  \nBlack excellence in tech: Panelist Spotlight...
# ...

# %%
news_df = news_df.rename(columns={'content': 'original'})
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                              original  \
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %%
news_df['clean'] = news_df['original'].apply(basic_clean)
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                              original  \
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %%
news_df['clean'] = news_df['clean'].apply(tokenize)
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                              original  \
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %%
news_df['clean'] = news_df['clean'].apply(remove_stopwords)
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                              original  \
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %%
news_df['stemmed'] = news_df['clean'].apply(stem_func)
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                              original  \
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %%
news_df['lemmatized'] = news_df['clean'].apply(lemmatize)
news_df
# Out:
#          category                                              title  \
# 0        business  Sachin Tendulkar and his wife meet Bill Gates;...
# 1        business  'Best wishes to my classmate,' writes Gates in...
# 2        business  Ambanis should get Z+ security cover across In...
# 3        business  Apple supplier Foxlink's fire safety systems f...
# 4        business  People consuming 30 GB and paying almost nothi...
# ..            ...                                                ...
# 95  entertainment  Naseeruddin thanked God for less romantic scen...
# 96  entertainment  Courteney gets star on H'wood Walk of Fame, An...
# 97  entertainment  Ram Charan's RC15 to clash with Kamal Haasan's...
# 98  entertainment  Reactions to trailer are too special: Rani on ...
# 99  entertainment  Said sorry to mom after doing underwear ad: Mi...
#
#                                              original  \
# 0   Former cricketer Sachin Tendulkar and his wife...
# ...

# %% [markdown]
# 9. Ask yourself:
#
# - If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?

# %% [markdown]
# Depending on the project and what you determine to be significant, lemmatizing might be the better option, because you can keep more of the word and it will process the words more thoroughly.

# %% [markdown]
# - If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?

# %% [markdown]
# Again, it would depend on the project and how much time you have to complete the project. With that said, stemming might be better with 25MB.

# %% [markdown]
# - If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?

# %% [markdown]
# Stemming would be faster than lemmatizing and would, therefore, be cheaper in the long rong.
